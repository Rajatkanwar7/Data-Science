# %% [markdown]
# ## Q1. What is the mathematical formula for a linear SVM?

# %% [markdown]
# ### Ans:
# The mathematical formula for a linear SVM can be expressed as:
#
# Given a set of training data {(x₁, y₁), (x₂, y₂), ..., (xn, yn)}, where xi is the i-th input vector and yi is the corresponding output label, with yi ∈ {-1, +1}, a linear SVM seeks to find the hyperplane that best separates the positive and negative examples in the input space.
#
# The hyperplane can be represented as:
#
# #### w*x + b = 0
#
# where w is the weight vector perpendicular to the hyperplane, x is the input vector, and b is the bias term.
#
# #### The objective of the SVM is to find the values of w and b that minimize the following cost function:
#
# minimize (1/2) * ||w||²
#
# subject to yi(w*x + b) ≥ 1
#
# where ||w|| is the norm of the weight vector, and the inequality constraint ensures that each training example is correctly classified and lies on the correct side of the hyperplane.
#
# Once the optimal values of w and b are found, the hyperplane can be used to predict the class of new, unseen data points by simply evaluating the sign of w*x + b.

# %% [markdown]
# ## Q2. What is the objective function of a linear SVM?

# %% [markdown]
# ### Ans:
#
# The objective function of a linear Support Vector Machine (SVM) is to find the hyperplane that best separates the positive and negative examples in the input space while maximizing the margin between the hyperplane and the closest data points. The margin is defined as the distance between the hyperplane and the closest points from both the positive and negative classes. The objective of the SVM is to find the values of the weight vector w and the bias term b that minimize the following cost function:
#
# minimize (1/2) * ||w||²
#
# subject to yi(w*x + b) ≥ 1
#
# where ||w|| is the norm of the weight vector, and the inequality constraint ensures that each training example is correctly classified and lies on the correct side of the hyperplane.

# %% [markdown]
# ## Q3. What is the kernel trick in SVM?

# %% [markdown]
# ### Ans:
#
# The kernel trick is a technique used in Support Vector Machines (SVMs) that allows them to efficiently learn non-linear decision boundaries by transforming the input data into a higher dimensional feature space. The idea behind the kernel trick is to implicitly map the input data into a high-dimensional feature space without actually computing the coordinates of the data in that space. This is achieved by defining a kernel function that computes the dot product between the transformed input vectors in the feature space.

# %% [markdown]
# ## Q4. What is the role of support vectors in SVM Explain with example.

# %% [markdown]
# ### Ans:
#
# Support vectors are the data points that lie closest to the decision boundary or hyperplane of a Support Vector Machine (SVM). These data points play a crucial role in defining the decision boundary and determining the optimal values of the weight vector and bias term during the training process.
#
# In SVM, the goal is to find the hyperplane that maximizes the margin between the closest points from both the positive and negative classes. The closest points from both classes that lie on either side of the decision boundary are called support vectors. These points define the margin and have a non-zero Lagrange multiplier in the optimization problem.
#
# During the training process, the SVM algorithm only considers the support vectors and their corresponding Lagrange multipliers to compute the decision boundary. This is because the non-support vectors do not have any impact on the decision boundary since they lie far away from it and do not contribute to the margin.
#
# For example, let's say we have a binary classification problem with two classes, red and blue, and we want to use an SVM to find the decision boundary that separates the two classes. The SVM algorithm will find the hyperplane that maximizes the margin between the closest points from both classes, which are the support vectors.
#
# Suppose that we have three red points and three blue points, as shown in the figure below. In this case, the support vectors are the red point on the left and the blue point on the right, which lie closest to the decision boundary.
# SVM Support Vectors Example
#
# During the training process, the SVM algorithm only considers these two points and their corresponding Lagrange multipliers to compute the optimal values of the weight vector and bias term that define the decision boundary. The remaining points are ignored, as they do not contribute to the margin and lie far away from the decision boundary.

# %% [markdown]
# ## Q5. Illustrate with examples and graphs of Hyperplane, Marginal plane, Soft margin and Hard margin in  SVM?

# %% [markdown]
# ### Ans:
#
# 1. Hyperplane:
# In SVM, the hyperplane is the decision boundary that separates the data points into different classes. In a binary classification problem, the hyperplane is a line that divides the feature space into two regions, one for each class. The goal of SVM is to find the hyperplane that maximizes the margin between the two classes.
# 2. Marginal plane:
# In SVM, the marginal plane is a plane that is parallel to the hyperplane and touches the support vectors on both sides. The distance between the hyperplane and the marginal plane is called the margin, and the goal of SVM is to maximize this margin. The marginal plane defines the boundary beyond which the SVM does not penalize errors.
# 3. Soft margin:
# In some cases, the data points may not be linearly separable, and it may not be possible to find a hyperplane that perfectly separates the two classes. In such cases, we can use a soft margin SVM, which allows for some misclassification errors by allowing some data points to be on the wrong side of the hyperplane. The degree of misclassification is controlled by a parameter called the C parameter, which penalizes misclassification errors.
# 4. Hard margin:
# In contrast to soft margin SVM, a hard margin SVM requires that all data points be correctly classified and that there is a clear separation between the two classes. A hard margin SVM is only appropriate when the data is linearly separable, and there are no misclassification errors.

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn import svm
# Generate some data for binary classification
X = np.array([[1, 2], [2, 3], [3, 3], [2, 1], [3, 2], [4, 1]])
y = np.array([1, 1, 1, -1, -1, -1])
# Create an SVM classifier with a linear kernel
clf = svm.SVC(kernel='linear', C=1)
# Fit the classifier to the data
clf.fit(X, y)
# Get the weights and bias term
w = clf.coef_[0]
b = clf.intercept_
# Get the support vectors
sv = clf.support_vectors_
# Get the hyperplane
x1 = np.linspace(np.min(X[:, 0]), np.max(X[:, 0]), 10)
x2 = -(w[0]*x1 + b) / w[1]
# Get the marginal plane
m1 = x2 + 1/w[1]
m2 = x2 - 1/w[1]
# Plot the data points
plt.scatter(X[:, 0], X[:, 1], c=y)
# Plot the hyperplane
plt.plot(x1, x2, 'k-')
# Plot the marginal planes
plt.plot(x1, m1, 'k--')
plt.plot(x1, m2, 'k--')
# Plot the support vectors
plt.scatter(sv[:, 0], sv[:, 1], s=100, facecolors='none', edgecolors='k')
# Set the axis limits and show the plot
plt.xlim(np.min(X[:, 0])-1, np.max(X[:, 0])+1)
plt.ylim(np.min(X[:, 1])-1, np.max(X[:, 1])+1)
plt.show()

# %% [markdown]
# As you can see from the plot, the hyperplane separates the two classes, the marginal planes are parallel to the hyperplane and just touch the support vectors, and the support vectors are the data points that lie closest to the hyperplane. We can also see that the soft margin SVM allows some data points to be misclassified, while the hard margin SVM does not.

# %% [markdown]
# ## Q6. SVM Implementation through Iris dataset.

# %% [markdown]
# ### 1.  Load the iris dataset from the scikit-learn library and split it into a training set and a testing set

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
from warnings import filterwarnings
filterwarnings('ignore')

# %%
# Load IRIS dataset from sklearn
from sklearn.datasets import load_iris
dataset = load_iris()

# %%
print(dataset.DESCR)
# Out:
# .. _iris_dataset:
#
# Iris plants dataset
# --------------------
#
# **Data Set Characteristics:**
#
#     :Number of Instances: 150 (50 in each of three classes)
#     :Number of Attributes: 4 numeric, predictive attributes and the class
#     :Attribute Information:
#         - sepal length in cm
#         - sepal width in cm
#         - petal length in cm
#         - petal width in cm
#         - class:
#                 - Iris-Setosa
#                 - Iris-Versicolour
#                 - Iris-Virginica
#
#     :Summary Statistics:
#
#     ============== ==== ==== ======= ===== ====================
#                     Min  Max   Mean    SD   Class Correlation
#     ============== ==== ==== ======= ===== ====================
#     sepal length:   4.3  7.9   5.84   0.83    0.7826
#     sepal width:    2.0  4.4   3.05   0.43   -0.4194
#     petal length:   1.0  6.9   3.76   1.76    0.9490  (high!)
#     petal width:    0.1  2.5   1.20   0.76    0.9565  (high!)
# ...

# %%
X =pd.DataFrame(dataset.data, columns=dataset.feature_names)
X.head()
# Out:
#    sepal length (cm)  sepal width (cm)  petal length (cm)  petal width (cm)
# 0                5.1               3.5                1.4               0.2
# 1                4.9               3.0                1.4               0.2
# 2                4.7               3.2                1.3               0.2
# 3                4.6               3.1                1.5               0.2
# 4                5.0               3.6                1.4               0.2

# %%
Y = pd.DataFrame(dataset.target, columns=['class'])
Y.head()
# Out:
#    class
# 0      0
# 1      0
# 2      0
# 3      0
# 4      0

# %%
from sklearn.model_selection import train_test_split
# Split the dataset into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X,Y,test_size=0.2, random_state=42)
# Print the shapes of the training and testing sets
print("X_train shape:", X_train.shape)
print("y_train shape:", y_train.shape)
# Out:
# X_train shape: (120, 4)
# y_train shape: (120, 1)

# %% [markdown]
# ## Train a linear SVM classifier on the training set and predict the labels for the testing set

# %%
from sklearn.svm import SVC
from sklearn.metrics import accuracy_score
# Train a linear SVM classifier
svm_clf = SVC(kernel='linear', C=1)
svm_clf.fit(X_train, y_train)
# Make predictions on the testing set
y_pred = svm_clf.predict(X_test)
print(y_pred)
# Out:
# [1 0 2 1 1 0 1 2 1 1 2 0 0 0 0 1 2 1 1 2 0 2 0 2 2 2 2 2 0 0]

# %%
# Calculate the accuracy of the SVM classifier
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 1.0

# %% [markdown]
# ### Compute the accuracy of the model on the testing set

# %%
from sklearn.metrics import accuracy_score
# y_test contains the true labels for the testing set
# y_pred contains the predicted labels for the testing set
accuracy = accuracy_score(y_test, y_pred)
print("Accuracy on testing set:", accuracy)
# Out:
# Accuracy on testing set: 1.0

# %% [markdown]
# ###  Plot the decision boundaries of the trained model using two of the features

# %%
# Plot the decision boundaries of the trained model using two of the features
import seaborn as sns
import matplotlib.pyplot as plt
df_train = pd.concat([X_train,y_train],axis=1)
sns.scatterplot(data = df_train, x = 'sepal length (cm)',y='sepal width (cm)',hue='class')
plt.title('Sepal Length vs Sepal width hueplot')
plt.show()

# %%
# Pairplot
sns.pairplot(df_train,hue='class')
plt.show()

# %% [markdown]
# ### Try different values of the regularisation parameter C and see how it affects the performance of the model.

# %%
import numpy as np
C = np.linspace(0.01,10,20)
C
# Out:
# array([ 0.01      ,  0.53578947,  1.06157895,  1.58736842,  2.11315789,
#         2.63894737,  3.16473684,  3.69052632,  4.21631579,  4.74210526,
#         5.26789474,  5.79368421,  6.31947368,  6.84526316,  7.37105263,
#         7.89684211,  8.42263158,  8.94842105,  9.47421053, 10.        ])

# %%
from sklearn.metrics import classification_report
acc = []
for i in C:
    model = SVC(kernel='linear', C=i)
    model.fit(X_train,y_train.values.flatten())
    ytest_pred = model.predict(X_test)
    acc.append(accuracy_score(y_test,ytest_pred))
    print(f'C Value : {i}\n')
    print(classification_report(y_test,ytest_pred))
    print('\n======================================================================\n')
# Out:
# C Value : 0.01
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       0.90      1.00      0.95         9
#            2       1.00      0.91      0.95        11
#
#     accuracy                           0.97        30
#    macro avg       0.97      0.97      0.97        30
# weighted avg       0.97      0.97      0.97        30
#
#
# ...
#
# C Value : 0.5357894736842106
#
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00        10
#            1       1.00      1.00      1.00         9
#            2       1.00      1.00      1.00        11
#
#     accuracy                           1.00        30
#    macro avg       1.00      1.00      1.00        30
# weighted avg       1.00      1.00      1.00        30
#
#
# ...
#
# C Value : 1.0615789473684212
#
#               precision    recall  f1-score   support
#
# ...

# %%
import matplotlib.pyplot as plt
plt.plot(C, acc)
plt.xlabel('C value')
plt.ylabel('Testing Accuracy')
plt.title('Accuracies for different values of C')
plt.show()
