# %% [markdown]
# Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of
# Matplotlib.

# %% [markdown]
# Ans:
# Matplotlib is a plotting library in Python used to create interactive visualizations in Python. It provides a wide range of tools to build visualizations of varying complexity.
#
# Matplotlib is used to visualize data in a variety of formats including line plots, scatter plots, histograms, bar plots, error bars, and many more.
#
#
# Here are five plots that can be plotted using the Pyplot module of Matplotlib:
# 1. Line Plot: A line plot is a graph that shows a series of data points connected by straight lines. It is useful for showing trends in data over time.
# 2. Scatter Plot: A scatter plot is a graph that uses dots to represent data points. It is useful for showing the relationship between two variables.
# 3. Bar Plot: A bar plot is a graph that represents data with rectangular bars. It is useful for comparing data between different groups.
# 4. Histogram: A histogram is a graph that shows the distribution of a dataset. It is useful for showing the frequency of different values in a dataset.
# 5. Pie Chart: A pie chart is a circular graph that shows the proportion of different categories in a dataset. It is useful for showing the relative size of different categories in a dataset.

# %% [markdown]
# Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# plot a scatter plot.
#
# import numpy as np
#
# np.random.seed(3)
#
# x = 3 + np.random.normal(0, 2, 50)
#
# y = 3 + np.random.normal(0, 2, len(x))
#
# Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Ans:
#
# A scatter plot is a type of plot that displays values for two variables as a collection of points, where each point represents an observation. It is commonly used to investigate the relationship between two variables.

# %%
import matplotlib.pyplot as plt
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x, y)
plt.title("Scatter Plot of X and Y")
plt.xlabel(" X variables ")
plt.ylabel("Y variables")
plt.show()

# %% [markdown]
# Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
#
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and  y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans:
#
# The subplot() function is used to create multiple plots in a single figure.

# %%
import numpy as np
import matplotlib.pyplot as plt
# Data for line 1
x1 = np.array([0, 1, 2, 3, 4, 5])
y1 = np.array([0, 100, 200, 300, 400, 500])
# Data for line 2
x2 = np.array([0, 1, 2, 3, 4, 5])
y2 = np.array([50, 20, 40, 20, 60, 70])
# Data for line 3
x3 = np.array([0, 1, 2, 3, 4, 5])
y3 = np.array([10, 20, 30, 40, 50, 60])
# Data for line 4
x4 = np.array([0, 1, 2, 3, 4, 5])
y4 = np.array([200, 350, 250, 550, 450, 150])
# Creating subplots
fig, axs = plt.subplots(2, 2)
# Plotting line 1
axs[0, 0].plot(x1, y1)
axs[0, 0].set_title('Line 1')
# Plotting line 2
axs[0, 1].plot(x2, y2)
axs[0, 1].set_title('Line 2')
# Plotting line 3
axs[1, 0].plot(x3, y3)
axs[1, 0].set_title('Line 3')
# Plotting line 4
axs[1, 1].plot(x4, y4)
axs[1, 1].set_title('Line 4')
# Adjusting layout
fig.tight_layout()
# Displaying plot
plt.show()

# %% [markdown]
# Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
#
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans:
#
# A bar plot is a plot that represents data using rectangular bars. It is used to compare data across different categories.
# To plot a bar plot and a horizontal bar plot using the given data, we can use the bar() and barh() functions of Matplotlib, respectively.

# %%
import matplotlib.pyplot as plt
import numpy as np
company = np.array(["Apple", "Microsoft", "Google", "AMD"])
profit = np.array([3000, 8000, 1000, 10000])
# Bar plot
plt.bar(company, profit)
plt.title("Company profits")
plt.xlabel("Company")
plt.ylabel("Profit (in millions)")
plt.show()
# Horizontal bar plot
plt.barh(company, profit)
plt.title("Company profits")
plt.xlabel("Profit (in millions)")
plt.ylabel("Company")
plt.show()

# %% [markdown]
# Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans:
# A box plot is a graphical representation of the distribution of data based on five summary statistics: minimum, first quartile, median, third quartile, and maximum. It is used to identify outliers and to compare the distributions of two or more datasets.

# %%
import matplotlib.pyplot as plt
import numpy as np
box1 = np.random.normal(100, 10, 200)
box2 = np.random.normal(90, 20, 200)
data = [box1, box2]
# Creating axes instance
fig, ax = plt.subplots()
# Creating axes instance
bp = ax.boxplot(data)
# Changing color and linewidth of whiskers
for whisker in bp['whiskers']:
    whisker.set(color='#8B008B', linewidth=1.5)
# Changing color and linewidth of caps
for cap in bp['caps']:
    cap.set(color='#8B008B', linewidth=2)
# Changing color and linewidth of medians
for median in bp['medians']:
    median.set(color='#FF1493', linewidth=3)
# Changing style of fliers
for flier in bp['fliers']:
    flier.set(marker='D', color='#e7298a', alpha=0.5)
# Adding title and axis labels
ax.set_title('Box plot for Box1 and Box2')
ax.set_xlabel('Box')
ax.set_ylabel('Value')
# Removing top axes and right axes ticks
ax.get_xaxis().tick_bottom()
ax.get_yaxis().tick_left()
# Show plot
plt.show()
